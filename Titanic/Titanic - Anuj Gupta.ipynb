# %%
import pandas as pd
from pandas import DataFrame
import matplotlib
import os
import numpy as np

# %% [markdown]
# # Phase I - Data importing

# %%
# "df" acts as a back up Data Frame containing original data, as is - it's not used 
# directly in the analysis
df = pd.read_csv('/Users/anujgupta/Documents/pythonds/3250_Foundation of DS/Assignments/Assignment 2 - Titanic/TitanicDataset.csv')
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
# "df2" is the working copy of the data frame used for analysis, and contains
# only the attributes & data being used 
df2 = pd.read_csv(
    '/Users/anujgupta/Documents/pythonds/Assignments/Assignment 2 - Titanic/TitanicDataset.csv',
    usecols = ["Survived","Pclass","Sex","Age"],
    na_values = '--',
    dtype = {"Pclass":int})
    
df2.head(10)
# Out:
#    Survived  Pclass     Sex   Age
# 0         0       3    male  22.0
# 1         1       1  female  38.0
# 2         1       3  female  26.0
# 3         1       1  female  35.0
# 4         0       3    male  35.0
# 5         0       3    male   NaN
# 6         0       1    male  54.0
# 7         0       3    male   2.0
# 8         1       3  female  27.0
# 9         1       2  female  14.0

# %%
df2.isnull().sum()
# Out:
# Survived      0
# Pclass        0
# Sex           0
# Age         177
# dtype: int64

# %% [markdown]
# # Phase 2 - Data cleansing & engineering

# %%
df2 = df2.fillna(df2.mean())
df2.head(20)
# Out:
#     Survived  Pclass     Sex        Age
# 0          0       3    male  22.000000
# 1          1       1  female  38.000000
# 2          1       3  female  26.000000
# 3          1       1  female  35.000000
# 4          0       3    male  35.000000
# 5          0       3    male  29.699118
# 6          0       1    male  54.000000
# 7          0       3    male   2.000000
# 8          1       3  female  27.000000
# 9          1       2  female  14.000000
# 10         1       3  female   4.000000
# 11         1       1  female  58.000000
# 12         0       3    male  20.000000
# 13         0       3    male  39.000000
# 14         0       3  female  14.000000
# 15         1       2  female  55.000000
# 16         0       3    male   2.000000
# 17         1       2    male  29.699118
# 18         0       3  female  31.000000
# 19         1       3  female  29.699118

# %%
# Adding an attribute that will group passengers in different age groups
df2["Passenger"]="default"
df2.head()
# Out:
#    Survived  Pclass     Sex   Age Passenger
# 0         0       3    male  22.0   default
# 1         1       1  female  38.0   default
# 2         1       3  female  26.0   default
# 3         1       1  female  35.0   default
# 4         0       3    male  35.0   default

# %%
# Converting Age into integer for sake of simplicity 
df2['Age'] = df2['Age'].astype(int)
df2.head()
# Out:
#    Survived  Pclass     Sex  Age Passenger
# 0         0       3    male   22   default
# 1         1       1  female   38   default
# 2         1       3  female   26   default
# 3         1       1  female   35   default
# 4         0       3    male   35   default

# %%
# Categorizing passengers into different age groups to determine if a certain 
# age group was given preference over the other in rescue operation

df2.loc[df2['Age']<16, ['Passenger']] = "Child"
df2.loc[df2['Age']>=65, ['Passenger']] = "Senior"
df2.loc[(df2['Age']>=16) & (df2['Age']<25), ['Passenger']] = "Youth"
df2.loc[(df2['Age']>=25) & (df2['Age']<65), ['Passenger']] = "Adult"
df2.head(7)
# Out:
#    Survived  Pclass     Sex  Age Passenger
# 0         0       3    male   22     Youth
# 1         1       1  female   38     Adult
# 2         1       3  female   26     Adult
# 3         1       1  female   35     Adult
# 4         0       3    male   35     Adult
# 5         0       3    male   29     Adult
# 6         0       1    male   54     Adult

# %%
# Adding more columns from "df" to "df2" to establish further relationships 
# And calculating total number of family members onboard for every passenger
df2["Siblings"] = df["SibSp"]  
df2["Parents"] = df["Parch"]
df2["Companions"] = df2["Siblings"] + df2["Parents"]
df2.head()
# Out:
#    Survived  Pclass     Sex  Age Passenger  Siblings  Parents  Companions
# 0         0       3    male   22     Youth         1        0           1
# 1         1       1  female   38     Adult         1        0           1
# 2         1       3  female   26     Adult         0        0           0
# 3         1       1  female   35     Adult         1        0           1
# 4         0       3    male   35     Adult         0        0           0

# %%
# Determining whether a passenger is traveling with family or alone, to find out
# whether accompanying family impacts the probability of survival
def family(comps):
    if comps.loc['Companions']==0:
        return "Alone"
    else:
        return "With family"
    
df2['Traveling'] = df2[["Age", "Companions"]].apply(family, axis=1)
df2.head()
# Out:
#    Survived  Pclass     Sex  Age Passenger  Siblings  Parents  Companions  \
# 0         0       3    male   22     Youth         1        0           1
# 1         1       1  female   38     Adult         1        0           1
# 2         1       3  female   26     Adult         0        0           0
# 3         1       1  female   35     Adult         1        0           1
# 4         0       3    male   35     Adult         0        0           0
#
#      Traveling
# 0  With family
# 1  With family
# 2        Alone
# 3  With family
# 4        Alone

# %% [markdown]
# # Phase 3 - Analysis

# %%
df2[['Survived', 'Pclass']].groupby(['Pclass']).mean().sort_values(by='Survived', ascending=False)
# Out:
#         Survived
# Pclass
# 1       0.629630
# 2       0.472826
# 3       0.242363

# %% [markdown]
# Conclusion 1: Above analysis shows that survival rate was directly propotional with the class
#               that a passenger was traveling in - hinting towards a systematic rescue approach
#               focusing on Class 1, followed by Class 2 and eventually Class 3

# %%
survivors = df2[['Survived', 'Pclass', 'Sex', 'Traveling']].groupby(['Pclass', 'Sex', 'Traveling']).mean()
survivors
# Out:
#                            Survived
# Pclass Sex    Traveling
# 1      female Alone        0.970588
#               With family  0.966667
#        male   Alone        0.333333
#               With family  0.425532
# 2      female Alone        0.906250
#               With family  0.931818
#        male   Alone        0.097222
#               With family  0.277778
# 3      female Alone        0.616667
#               With family  0.416667
#        male   Alone        0.121212
#               With family  0.180723

# %%
survivors_fam = df2[['Survived','Traveling']].groupby('Traveling').mean()
survivors_fam
# Out:
#              Survived
# Traveling
# Alone        0.303538
# With family  0.505650

# %% [raw]
# Conclusion 2: Further looking at accompanying family members for every passenger, it can
#               safely be concluded that those passengers traveling with family had a fairly
#               better chance of survival than those traveling alone

# %%
survivors_sex = df2[['Survived','Sex']].groupby('Sex').mean()
survivors_sex
# Out:
#         Survived
# Sex
# female  0.742038
# male    0.188908

# %% [raw]
# Conclusion 3: A look at the genders clearly suggests female passengers had a significantly
#               higher chance of survival than male passengers

# %%
survivors_age = df2[["Passenger", "Survived", "Sex"]].groupby(["Sex", "Passenger"]).mean()
survivors_age
# Out:
#                   Survived
# Sex    Passenger
# female Adult      0.751269
#        Child      0.651163
#        Youth      0.770270
# male   Adult      0.185185
#        Child      0.525000
#        Senior     0.090909
#        Youth      0.099174

# %% [raw]
# Conclusion 4: The above clearly shows that while with females all the age groups had more or
#               less similar survival rate, children had the highest chances of survival
#               among the male passengers.
#
#               The above assessment also suggests that barring children, male passengers of any
#               other age category had very little chances of survival.

# %% [markdown]
# # Phase 4 - Results and answers

# %% [raw]
# Q1. Categories of passengers most likely to survive the Titanic disaster:
#     - Females
#     - Class 1 passengers, followed by Class 2 and then class 3
#     - Children under 16 years of age among the male passengers
#     - Those accompanied by family members

# %% [raw]
# Q2. Attributes used, including the ones specified:
#     - Age (prescribed)
#     - Gender (prescribed)
#     - Cabin class (prescribed)
#   * - Siblings (additional)
#   * - Parents (additional)
#
# The two additional attributes are used to determine if having family members onboard impacted the chances of one's survival, and if so, how.
#
# These two attributes are used to engineer a new attribute specifying whether a passenger was alone or had family, which forms the basis of aforementioned analysis.

# %% [raw]
# Q3. Engineered attributes:
#     - Passenger age group (Children / Youth / Adults / Seniors)
#     - Number of companions (including siblings and parents)
#     - Traveling (with family or alone - derived from number of companions)
#
# These attributes are created to determine more hidden relationships between survival rate and the data provided.
# a) Age was used to categorize passengers into different groups, and thereby assessing the survival rate. By itself, age would not have been of help being continuos data, and thus classification helps divide the data set into identifiable subsets
# b) As explained in the previous section, Siblings and Parents helped determine whether a passenger was traveling alone or had companions, which helps analyze the difference having family onboard made in one's survival

# %% [raw]
# Q4. Excluded attributes:
#     - Price paid for ticket
#     - Boarding place
#     - Cabin number
#     - Ticket number
#
# Rationale behind excluding the variables:
# a) Price paid and ticket number - It is assumed that the differences in prices and ticket numbers get reflected in cabin class (1/2/3) or the age. For example - children and seniors may be charged lesser for their tickets in Class 1, but the price may still be equal or more than an adult ticket in Class 3
# b) Boarding place and cabin number - It is assumed that cabin numbers are a function of cabin class, which has been used in the analysis. Also, boarding place is excluded since passengers boarding from latter ports may still get their cabins nearer to the ones already onboard, depending upon the class, and hence may be irrelavant for analysis

# %% [raw]
# Q5. Missing values in Age column have been replaced with the average age of the rest of the passengers, so as to not skew our results. Comparing with removing rows (177 / 891) with missing age values:
# a) This makes no change in the average age of the passengers being analyzed
# b) Gives us nearly 25% extra records to base our analysis upon, with 5 given and 3 engineered attributes per record
